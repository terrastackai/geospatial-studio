# %% [markdown]
# ![Geospatial Studio banner](../docs/images/banner.png)
#
# # 🌍 Geospatial Exploration and Orchestration Studio
#
# ## Training a Custom Model for Wildfire Burn Scar Detection
#
# <table>
# <tr>
#   <td><strong>License</strong></td>
#   <td>
#     <img src="https://img.shields.io/badge/License-Apache_2.0-blue.svg" />
#   </td>
# </tr>
# <tr>
#   <td><strong>TerraStackAI</strong></td>
#   <td>
#     <img src="https://img.shields.io/badge/TerraTorch-a3b18a" />
#     <img src="https://img.shields.io/badge/TerraKit-588157" />
#     <img src="https://img.shields.io/badge/Iterate-3a5a40" />
#   </td>
# </tr>
# <tr>
#   <td><strong>Built With</strong></td>
#   <td>
#     <img src="https://img.shields.io/badge/Python-3.11-blue.svg?logo=python&logoColor=white" />
#     <img src="https://img.shields.io/badge/code%20style-black-000000.svg" />
#     <img src=https://img.shields.io/badge/pre--commit-enabled-brightgreen?logo=pre-commit&logoColor=white />
#
#   </td>
# </tr>
# <tr>
#   <td><strong>Deployment</strong></td>
#   <td>
#     <img src="https://img.shields.io/badge/Helm-0F1689?style=flat&logo=helm" />
#     <img src="https://img.shields.io/badge/-Red_Hat_OpenShift-EE0000?logo=redhatopenshift&logoColor=white" />
#     <img src="https://img.shields.io/badge/kubernetes-326CE5?&logo=kubernetes&logoColor=white" />
#     <img src="https://img.shields.io/badge/Auth-OAuth_2.0-purple" />
#     <img src="https://img.shields.io/badge/PostgreSQL-316192?logo=postgresql&logoColor=white" />
#     <img src="https://img.shields.io/badge/Keycloak-111921?logo=keycloak&logoColor=white" />
#     <img src="https://img.shields.io/badge/-MinIO-C72E49?logo=minio&logoColor=white" />
#   </td>
# </tr>
# </table>
#
# [![Studio Documentation](https://img.shields.io/badge/Studio_Documentation-526CFE?style=for-the-badge&logo=MaterialForMkDocs&logoColor=white)](https://terrastackai.github.io/geospatial-studio)
#
# ---

# %% [markdown]
# ## 1.0 Introduction

# %% [markdown]
# Welcome to this hands-on workshop on **burn scar detection** using the Geospatial Studio! This tutorial will guide you through the complete workflow of fine-tuning a geospatial foundation model and running inference to identify burn scars from satellite imagery.
#
# **What you'll learn:**
# - Setting up and connecting to the Geospatial Studio platform
# - Fine-tuning models for burn scar segmentation tasks with pre-trained foundation models and datasets
# - Running inference on real-world wildfire data (Park Fire, California)
# - Visualizing and analyzing results in the Studio UI
# - Comparing results with a better trained model
#
# **Prerequisites:**
# - A deployed instance of the Geospatial Studio
# - Access to GPU resources (for fine-tuning section)
# - Basic familiarity with Python and Jupyter notebooks

# %% [markdown]
# ### 1.0.1 Understanding the Workflow

# %% [markdown]
# Before we begin, let's understand the complete workflow:
#
# ```mermaid
# graph LR
#     A[Foundation Model] --> D[Fine-tuning Job]
#     B[Training Dataset] --> D
#     C[Task Template] --> D
#     D --> E[Trained Model]
#     E --> F[Inference]
#     F --> G[Results]
#
#     style A fill:#1f77b4,stroke:#333,stroke-width:2px,color:#fff
#     style B fill:#1f77b4,stroke:#333,stroke-width:2px,color:#fff
#     style C fill:#1f77b4,stroke:#333,stroke-width:2px,color:#fff
#     style D fill:#ff7f0e,stroke:#333,stroke-width:2px,color:#fff
#     style E fill:#2ca02c,stroke:#333,stroke-width:2px,color:#fff
#     style F fill:#d62728,stroke:#333,stroke-width:2px,color:#fff
#     style G fill:#9467bd,stroke:#333,stroke-width:2px,color:#fff
# ```
#
# **Key Components:**
#
# 1. **Foundation Model (Backbone)**: Pre-trained model with general geospatial understanding
# 2. **Training Dataset**: Labeled data for your specific task
# 3. **Task Template**: Configuration defining the learning task (from Lab 3)
# 4. **Fine-tuning Job**: Training process that customizes the model
# 5. **Trained Model (Tune)**: Your custom model checkpoint
# 6. **Inference**: Running predictions on new data
#
# ---

# %% [markdown]
# ### 1.0.2 Example: Burn Scar Detection Workflow

# %% [markdown]
# Below is an example of what you'll achieve in this workshop - detecting burn scars from satellite imagery using fine-tuned geospatial foundation models.
#
# #### Input Satellite Imagery
# Raw satellite data showing the area affected by wildfire:
#
# <!-- ![Fire Input](../assets/fire-input.png) -->
# <img src="../assets/fire-input.png" alt="RGB Input" width="588" height="300">
#
# #### Model Prediction
# The fine-tuned model identifies burn scar areas:
#
# <img src="../assets/fire-prediction.png" alt="Fire Prediction" width="588" height="300">
#
# #### Prediction Overlay
# Burn scar predictions overlaid on the original imagery for validation:
#
# <img src="../assets/fire-prediction-overlayed.png" alt="Fire Prediction Overlayed" width="588" height="300">
#
# <!-- ![Fire Prediction Overlayed](../assets/fire-prediction-overlayed.png) -->
#
# This workflow demonstrates the power of geospatial foundation models in identifying and mapping wildfire-affected areas, which is crucial for disaster response, environmental monitoring, and recovery planning.
#
#
# Let's get started by setting up your environment and connecting to the platform!

# %% [markdown]
# ### 1.1 Set up and  Installation

# %% [markdown]
# #### 1.1.0 Prerequisites
#
# Create a python environment
# ```bash
# python -m venv venv
# OR # depending on your available python version
# python3 -m venv venv
# source venv/bin/activate
# ```
# Install geostudio sdk
# ```bash
# pip install geostudio
# ```
#
# Set the jupyter notebook kernel to point to the above created python environment.

# %% [markdown]
# #### 1.1.1 Import required packages

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Import the required packages
import json
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
from geostudio import Client

# %% [markdown]
# ### 1.2 Connecting to the platform
# First, we set up the connection to the platform backend.  To do this we need the base url for the studio UI and an API key.
#
# To get an API Key:
# 1. Go to the provided cluster url of the deployed version of the Geospatial Studio UI page <uhere>[hrl to be provided here] and navigate to the Manage your API keys link.
# 2. This should pop-up a window where you can generate, access and delete your api keys. NB: every user is limited to a maximum of two activate api keys at any one time.
#
# Store the API key and geostudio ui base url in a credentials file locally, for example in /User/bob/.geostudio_config_file. You can do this by:
#
# ```bash
# echo "GEOSTUDIO_API_KEY=<paste_api_key_here>" > .geostudio_config_file
# echo "BASE_STUDIO_UI_URL=<paste_ui_base_url_here>" >> .geostudio_config_file
# ```
#
# Copy and paste the file path to this credentials file in call below. You will need to ensure that the `geostudio_config_file` is accessible and correctly configured. If you encounter any issues, please verify the file path and contents of the `.geostudio_config_file` to ensure they are accurate and up-to-date.

# %%
#############################################################
# Initialize Geostudio client using a geostudio config file
#############################################################
gfm_client = Client(geostudio_config_file=".geostudio_config_file")
# Out:
# Using api key and base urls from geostudio config file
# Using api key and base urls from geostudio config file
# Using api key and base urls from geostudio config file

# %% [markdown]
# ## 2.0 Burnscars dataset

# %% [markdown]
# ### 2.1 Reviewing already prepared and onboarded burn scars dataset
#
# In this section, we'll explore how to review datasets that have already been prepared and onboarded to the Geospatial Studio. This is useful for understanding what data is available before starting a fine-tuning task.

# %%
from pandas import DataFrame

# List all available datasets in the studio
datasets = gfm_client.list_datasets()['results']
display(DataFrame(datasets))
# Out:
#                                id  active        created_by  \
# 0  geodata-pecl5din5vpeytjxkwt3oa    True  test@example.com
# 1  geodata-4vdk3x6pyfvr59zxki6kcc    True  test@example.com
# 2  geodata-e8hwqfrvtsgwfgsx7agvgk    True  test@example.com
#
#                     created_at                   updated_at  \
# 0  2026-04-14T15:05:34.083544Z  2026-04-14T15:05:34.092497Z
# 1  2026-04-14T14:15:45.823626Z  2026-04-14T14:21:41.207514Z
# 2  2026-04-13T11:58:22.458637Z  2026-04-13T12:08:15.308968Z
#
#                      dataset_name  \
# 0                 sandbox-dataset
# 1  Sentinel Flood Multimodal Test
# 2             Wildfire burn scars
#
#                                          description  \
# 0                                    sandbox dataset
# 1                             Flood data from places
# 2  A set of wildfire burn scar extent using HLS d...
#
#                                          dataset_url    label_suffix  \
# 0                                https://example.com       .mask.tif
# 1  https://geospatial-studio-example-data.s3.us-e...  _LabelHand.tif
# 2  https://s3.us-east.cloud-object-storage.appdom...       .mask.tif
#
#         purpose                                       data_sources  \
# 0  Segmentation                                                 []
# 1  Segmentation  [{'bands': [{'index': '0', 'band_name': 'B01',...
# 2  Segmentation  [{'bands': [{'index': '0', 'band_name': 'Blue'...
#
#                                     label_categories     size     status  \
# 0                                                 []      0MB    Pending
# 1  [{'id': '0', 'name': 'No Floods', 'description...   1.8 GB  Succeeded
# 2  [{'id': '1', 'name': 'Fire Scar', 'color': '#a...  10.5 GB  Succeeded
#
#   error                                               logs onboarding_options
# 0                                                     None                 {}
# 1   N/A  dflogs/2026-04-14/geodata-4vdk3x6pyfvr59zxki6k...                 {}
# 2   N/A  dflogs/2026-04-13/geodata-e8hwqfrvtsgwfgsx7agv...                 {}

# %%
# Get detailed information about a specific burn scars dataset
# If you know the dataset name or ID, you can retrieve its details
burn_scars_dataset_id = "geodata-e8hwqfrvtsgwfgsx7agvgk"
burn_scars_dataset_id
# Out:
# 'geodata-e8hwqfrvtsgwfgsx7agvgk'

# %%
# Get detailed metadata for a specific dataset
# Replace with your actual dataset_id from the list above
dataset_details = gfm_client.get_dataset(burn_scars_dataset_id)
print(json.dumps(dataset_details, indent=2))
# Out:
# {
#   "id": "geodata-e8hwqfrvtsgwfgsx7agvgk",
#   "status": "Succeeded",
#   "updated_at": "2026-04-13T12:08:15.308968+00:00",
#   "training_data_suffix": null,
#   "error": "N/A",
#   "created_by": "test@example.com",
#   "custom_bands": null,
#   "version": "v2",
#   "updated_by": null,
#   "data_sources": [
#     {
#       "bands": [
#         {
#           "index": "0",
#           "band_name": "Blue",
#           "scaling_factor": "0.0001",
#           "RGB_band": "B"
#         },
#         {
#           "index": "1",
#           "band_name": "Green",
#           "scaling_factor": "0.0001",
#           "RGB_band": "G"
#         },
#         {
#           "index": "2",
#           "band_name": "Red",
#           "scaling_factor": "0.0001",
#           "RGB_band": "R"
#         },
#         {
#           "index": "3",
#           "band_name": "NIR_Narrow",
#           "scaling_factor": "0.0001"
#         },
#         {
#           "index": "4",
#           "band_name": "SWIR1",
#           "scaling_factor": "0.0001"
#         },
#         {
#           "index": "5",
#           "band_name": "SWIR2",
#           "scaling_factor": "0.0001"
#         }
#       ],
#       "connector": "sentinelhub",
#       "collection": "hls_l30",
#       "file_suffix": "_merged.tif",
#       "modality_tag": "HLS_L30"
#     }
#   ],
#   "logs": "dflogs/2026-04-13/geodata-e8hwqfrvtsgwfgsx7agvgk.log",
#   "active": true,
#   "purpose": "Segmentation",
#   "onboarding_options": {},
#   "deleted": false,
#   "dataset_url": "https://s3.us-east.cloud-object-storage.appdomain.cloud/geospatial-studio-example-data/burn-scar-training-data.zip",
#   "dataset_name": "Wildfire burn scars",
#   "label_categories": [
#     {
#       "id": "1",
#       "name": "Fire Scar",
#       "color": "#ab4f4f",
#       "opacity": 1
#     },
#     {
#       "id": "0",
#       "name": "No data",
#       "color": "#000000",
#       "opacity": "0"
#     },
#     {
#       "id": "-1",
#       "name": "Ignore",
#       "color": "#000000",
#       "opacity": "0"
#     }
#   ],
#   "created_at": "2026-04-13T11:58:22.458637+00:00",
#   "description": "A set of wildfire burn scar extent using HLS data.  This dataset contains Harmonized Landsat and Sentinel-2 imagery of burn scars and the associated masks for the years 2018-2021 over the contiguous United States. There are 804 512x512 scenes. Its primary purpose is for training geospatial machine learning models.  Each tiff file contains a 512x512 pixel tiff file. Scenes contain six bands, and masks have one band. For satellite scenes, each band has already been converted to reflectance.",
#   "training_params": {
#     "train_split_path": "/geodata-e8hwqfrvtsgwfgsx7agvgk/split_files/train_data.txt",
#     "test_split_path": "/geodata-e8hwqfrvtsgwfgsx7agvgk/split_files/test_data.txt",
#     "val_split_path": "/geodata-e8hwqfrvtsgwfgsx7agvgk/split_files/val_data.txt",
#     "HLS_L30": {
#       "norm_means": [
#         0.052501344674454685,
#         0.07818710276892571,
#         0.09527748749364956,
#         0.21442636938609524,
#         0.23594506038412516,
#         0.1707575734110789
#       ],
#       "norm_stds": [
#         0.02980933467336373,
#         0.03671671799312583,
#         0.054445047276513434,
#         0.06953507438690602,
#         0.09133826565407105,
#         0.08313280812483531
#       ],
#       "bands": [
#         0,
#         1,
#         2,
#         3,
#         4,
#         5
#       ],
#       "file_suffix": "*_merged.tif",
#       "train_data_dir": "/geodata-e8hwqfrvtsgwfgsx7agvgk/training_data/HLS_L30/",
#       "train_labels_dir": "/geodata-e8hwqfrvtsgwfgsx7agvgk/labels/",
#       "test_data_dir": "/geodata-e8hwqfrvtsgwfgsx7agvgk/training_data/HLS_L30/",
#       "test_labels_dir": "/geodata-e8hwqfrvtsgwfgsx7agvgk/labels/",
#       "val_data_dir": "/geodata-e8hwqfrvtsgwfgsx7agvgk/training_data/HLS_L30/",
#       "val_labels_dir": "/geodata-e8hwqfrvtsgwfgsx7agvgk/labels/"
#     },
#     "classes": [
#       "1",
#       "0",
#       "-1"
#     ]
#   },
#   "label_suffix": ".mask.tif",
#   "size": "10.5 GB",
#   "logs_presigned_url": "https://minio-api-gfm-be-staging.apps.fmaas-backend.fmaas.res.ibm.com/gfm-be-staging-dataset-factory/dflogs/2026-04-13/geodata-e8hwqfrvtsgwfgsx7agvgk.log?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=minioadmin%2F20260414%2Fus-east%2Fs3%2Faws4_request&X-Amz-Date=20260414T155717Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=89855802949428327a0032fa6003b29b2874a4dac2c418e0ba856b92d4ea0488"
# }

# %% [markdown]
# **From the above output, the dataset Configuration is:**
# - **6 spectral bands**: Blue, Green, Red, NIR, SWIR1, SWIR2
# - **3 label categories**: Fire Scar (1), No Data (0), Ignore (-1)
# - **File format**: GeoTIFF with `.mask.tif` suffix for labels
# - **Purpose**: Segmentation (pixel-level classification)

# %% [markdown]
# ## 3.0 Run a model training job

# %% [markdown]
# To ran a Finetuning job, we need:
# - A **base model**
# - A **dataset**
# - A **task template**
# ---
# ### 3.1 Select a Base Model
# ---
#
# For this task, we will use the **Prithvi-EO-V2-300M** foundation model as our base model. This is a 300-million parameter geospatial foundation model pre-trained on satellite imagery.
#
# **About Prithvi-EO-V2:**
# - Pre-trained on multi-spectral satellite data
# - Understands spatial and temporal patterns in Earth observation data
# - Serves as the starting point for fine-tuning
#
# The backbone configuration includes:
# - Model architecture parameters (embed_dim, num_heads, etc.)
# - Checkpoint file location
# - Model category and type

# %%
# List all the base models onboarded in the cluster
base_models = gfm_client.list_base_models()['results']
display(DataFrame(base_models))

# Select Prithvi_EO_V2_300M model
prithvi_eo_v2_300m_base_model_id = "28ad8b4f-13ba-4567-b28f-bb16758324c3"
# Out:
#                                       id  active        created_by  \
# 0   fdf47e1e-aa27-42c2-b5da-b82e8f608c9d    True  test@example.com
# 1   28ad8b4f-13ba-4567-b28f-bb16758324c3    True  test@example.com
# 2   3f44ad33-c219-4276-a848-b0be59840162    True  test@example.com
# 3   d1bbb2e4-1e62-4fe2-acba-bea4a27844d9    True  test@example.com
# 4   b9ec9903-cad8-4f21-8158-c9773517020c    True  test@example.com
# 5   a25fb18c-1adc-4900-ae7f-861e77974d67    True  test@example.com
# 6   2625ea64-08e1-4fc4-bb15-e39381509c92    True  test@example.com
# 7   ce05f5ee-5072-43cf-94b7-afa7f4db3ee3    True  test@example.com
# 8   ce8c98df-60a9-46c1-8fe7-12abf31027ac    True  test@example.com
# 9   9746f6c4-f661-4c11-b620-855dbc240443    True  test@example.com
# 10  69243ed8-d4ae-40b3-b79d-0ddce947fb2b    True  test@example.com
# 11  7f3d39c6-f822-42d9-9bfe-7adcb567ddb8    True  test@example.com
# 12  2926db99-99a7-4080-b238-17b62a374e58    True  test@example.com
# 13  5791f04e-2fdb-4051-a50a-ed2e15ca4909    True  test@example.com
# 14  a333acfa-c0c3-4d98-b298-48ff6a39e668    True  test@example.com
# 15  ae9ff088-287d-4f4e-9f53-1c10d2bc536a    True  test@example.com
# 16  895ba294-c60c-421e-b4a9-c4ac48d7b736    True  test@example.com
# 17  85280e0c-a1e9-4df7-8984-64ecbfcbaef5    True  test@example.com
# 18  95b64205-e9d8-44f4-a8dc-b462913321e3    True  test@example.com
# 19  ae2d2549-493e-4e13-84f3-67b9539a3277    True  test@example.com
# 20  08ab07a2-d8e8-4272-8d25-493b6909ece5    True  test@example.com
# 21  fc5cd72c-0b62-48b8-bf18-fef9c659bbc3    True  test@example.com
# 22  47d816dd-93c0-4a47-8d63-75adec84917d    True  test@example.com
# 23  dc9e8e30-f86a-460e-8e11-921f724b611f    True  test@example.com
# 24  0a19df61-9812-4783-9905-9705cdee863d    True  test@example.com
#
#                      created_at                   updated_at  \
# 0   2026-04-14T15:41:47.547111Z  2026-04-14T15:41:47.546069Z
# 1   2026-04-13T11:58:21.907733Z  2026-04-13T11:58:21.906120Z
# 2   2026-04-13T10:31:58.487067Z  2026-04-13T10:31:58.485729Z
# 3   2026-04-13T08:45:23.377923Z  2026-04-13T08:45:23.377782Z
# 4   2026-04-10T14:59:23.484688Z  2026-04-10T14:59:23.484437Z
# 5   2026-04-10T14:10:29.463868Z  2026-04-10T14:10:29.466537Z
# 6   2026-04-10T11:23:04.941694Z  2026-04-10T11:23:04.944172Z
# 7   2026-04-10T08:41:45.834341Z  2026-04-10T08:41:45.837797Z
# 8   2026-04-10T07:36:12.721230Z  2026-04-10T07:36:12.724356Z
# 9   2026-04-10T06:47:17.842714Z  2026-04-10T06:47:17.845568Z
# 10  2026-04-09T19:41:28.775937Z  2026-04-09T19:41:28.779354Z
# 11  2026-04-09T18:55:26.982207Z  2026-04-09T18:55:26.986505Z
# 12  2026-04-09T17:43:39.013392Z  2026-04-09T17:43:39.018798Z
# 13  2026-04-09T17:03:02.644818Z  2026-04-09T17:03:02.649473Z
# 14  2026-04-09T16:06:03.431942Z  2026-04-09T16:06:03.434798Z
# 15  2026-04-09T13:06:59.796110Z  2026-04-09T13:06:59.799504Z
# 16  2026-04-09T12:28:49.529512Z  2026-04-09T12:28:49.534635Z
# 17  2026-04-09T10:59:15.603281Z  2026-04-09T10:59:15.607356Z
# 18  2026-04-09T10:54:50.322079Z  2026-04-09T10:54:50.326569Z
# 19  2026-04-08T10:24:58.224633Z  2026-04-08T10:24:58.227050Z
# 20  2026-04-08T08:35:43.551937Z  2026-04-08T08:35:43.553576Z
# 21  2026-04-08T08:35:43.292590Z  2026-04-08T08:35:43.295010Z
# 22  2026-04-08T08:35:42.696589Z  2026-04-08T08:35:42.697882Z
# 23  2026-04-08T08:35:42.521771Z  2026-04-08T08:35:42.522286Z
# 24  2026-04-08T08:35:27.820374Z  2026-04-08T08:35:27.821164Z
#
#                   name                                        description  \
# 0    terramind_v1_tiny            Terramind Multimodal tiny backbone base
# 1   Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 2   Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 3   Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 4   Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 5   Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 6   Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 7   Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 8   Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 9   Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 10  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 11  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 12  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 13  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 14  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 15  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 16  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 17  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 18  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 19  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 20  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 21  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 22  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 23  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
# 24  Prithvi_EO_V2_300M  Geospatial pre-traineed foundation model Prith...
#
#                         checkpoint_filename  \
# 0    terramind_v1_tiny/terramind_v1_tiny.pt
# 1   prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 2   prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 3   prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 4   prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 5   prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 6   prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 7   prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 8   prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 9   prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 10  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 11  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 12  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 13  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 14  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 15  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 16  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 17  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 18  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 19  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 20  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 21  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 22  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 23  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
# 24  prithvi_eo_v2_300/Prithvi_EO_V2_300M.pt
#
#                                          model_params    status  shared
# 0   {'backbone': 'terramind_v1_tiny', 'embed_dim':...  Finished   False
# 1   {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 2   {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 3   {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 4   {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 5   {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 6   {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 7   {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 8   {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 9   {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 10  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 11  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 12  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 13  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 14  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 15  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 16  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 17  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 18  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 19  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 20  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 21  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 22  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 23  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False
# 24  {'backbone': 'prithvi_eo_v2_300', 'embed_dim':...  Finished   False

# %% [markdown]
# ---
# ### 3.2 Select a task template
# ---
#
# A **task template** defines:
# - The type of ML task (segmentation, regression, classification)
# - Model architecture options
# - Training hyperparameters
# - Default configurations
#
# ### Why Do We Need It?
#
# When you upload a model checkpoint, GEOStudio needs to know:
# 1. **What task** the model was trained for
# 2. **How to configure** the model for inference
# 3. **What inputs** the model expects
#
# ### Available Task Types
#
# - **Segmentation** - Pixel-wise classification (floods, burn scars, land cover)
# - **Regression** - Continuous value prediction (biomass, temperature)
# - **Classification** - Image-level labels (crop type, building detection)
# - **User-Defined** - Specific User defined templates for specific model use cases (convnext-template)
#
# For this example, we will be using the **Segmentation** task type.

# %%
# List all the templates onboarded in the cluster
tune_templates = gfm_client.list_tune_templates()['results']
display(DataFrame(tune_templates))

# Select segmentation template
segmentation_template_id = "8573acf1-5ee7-4291-bcfe-357408080445"
# Out:
#                                       id  active        created_by  \
# 0   ccf91f72-0a17-41f0-b835-5be3c901fe34    True  test@example.com
# 1   8573acf1-5ee7-4291-bcfe-357408080445    True  test@example.com
# 2   43618100-adba-4d37-afce-ef138e782006    True  test@example.com
# 3   b5c54414-1510-47c7-a58f-265b08b60274    True  test@example.com
# 4   06965b8a-bafb-4486-a204-54638f339857    True  test@example.com
# 5   9b02693f-9271-4556-9c9e-6c9e33116640    True  test@example.com
# 6   1b44aca3-1602-4597-ba27-cbad3b2a0156    True  test@example.com
# 7   6eba6a3d-7395-4188-a535-eef0f49b742a    True  test@example.com
# 8   9c34b43d-faef-4b10-8019-f12ef36491d9    True  test@example.com
# 9   ab2194a1-8e6b-4cfb-9a19-9d2c1fa8d25b    True  test@example.com
# 10  541e8866-2b53-41a0-af22-5bbe32b5230d    True  test@example.com
# 11  a53b02d8-313e-485f-bf59-6e19bf1c4c97    True  test@example.com
# 12  02cc6991-8644-4b0b-b42d-e5763548dd58    True  test@example.com
# 13  4cba3b34-2d6b-4e6d-8448-b93160a17d69    True  test@example.com
# 14  ca8e137f-c2af-4138-946e-5a63825e88a4    True  test@example.com
# 15  6a332fbc-bb48-4f25-ad7a-9a23fe495b61    True  test@example.com
# 16  87b0f823-f57b-4307-8c47-ceb3da539feb    True  test@example.com
# 17  fe19f6d0-27a5-4f87-9062-a7367ff31e72    True  test@example.com
# 18  87813857-89c0-48dd-a201-9cfc79da73a8    True  test@example.com
# 19  949d509d-ff14-418e-a15f-8900a6c796d7    True  test@example.com
# 20  5bd17e83-e736-4a46-b137-92a18450f9f5    True  test@example.com
# 21  e02f7f5d-392a-4327-9e53-a44fd4ddffe5    True  test@example.com
# 22  86212af3-8e24-42c0-8a29-286bbb599dfc    True  test@example.com
# 23  355a54c0-a6bb-4b4c-a265-323427c6c636    True  test@example.com
# 24  7ec71675-d1a3-4cce-892f-491d52e8aaf1    True  test@example.com
#
#                      created_at                   updated_at  \
# 0   2026-04-14T15:42:16.127896Z  2026-04-14T15:42:16.126933Z
# 1   2026-04-13T12:09:44.438583Z  2026-04-13T12:09:44.436945Z
# 2   2026-04-13T11:55:56.620683Z  2026-04-13T11:55:56.619156Z
# 3   2026-04-13T11:53:46.355546Z  2026-04-13T11:53:46.354463Z
# 4   2026-04-13T10:41:25.133654Z  2026-04-13T10:41:25.132728Z
# 5   2026-04-13T10:30:15.673388Z  2026-04-13T10:30:15.671715Z
# 6   2026-04-13T10:28:36.365165Z  2026-04-13T10:28:36.363568Z
# 7   2026-04-13T08:54:39.905463Z  2026-04-13T08:54:39.906336Z
# 8   2026-04-13T08:43:44.971362Z  2026-04-13T08:43:44.970897Z
# 9   2026-04-10T15:08:12.314171Z  2026-04-10T15:08:12.312924Z
# 10  2026-04-10T14:57:46.201899Z  2026-04-10T14:57:46.202336Z
# 11  2026-04-10T14:41:35.321304Z  2026-04-10T14:41:35.323536Z
# 12  2026-04-10T14:36:28.545721Z  2026-04-10T14:36:28.544782Z
# 13  2026-04-10T14:32:10.778444Z  2026-04-10T14:32:10.777855Z
# 14  2026-04-10T14:29:33.496693Z  2026-04-10T14:29:33.497719Z
# 15  2026-04-10T14:22:34.773651Z  2026-04-10T14:22:34.775935Z
# 16  2026-04-10T14:14:57.460928Z  2026-04-10T14:14:57.462463Z
# 17  2026-04-10T14:13:01.980007Z  2026-04-10T14:13:01.982957Z
# 18  2026-04-10T14:10:49.349143Z  2026-04-10T14:10:49.355058Z
# 19  2026-04-10T14:10:06.877183Z  2026-04-10T14:10:06.880195Z
# 20  2026-04-10T11:30:33.042288Z  2026-04-10T11:30:33.045571Z
# 21  2026-04-10T11:21:22.860903Z  2026-04-10T11:21:22.867807Z
# 22  2026-04-10T08:49:33.160240Z  2026-04-10T08:49:33.164290Z
# 23  2026-04-10T08:40:05.356391Z  2026-04-10T08:40:05.360015Z
# 24  2026-04-10T07:43:56.636682Z  2026-04-10T07:43:56.640437Z
#
#                       name                                      description  \
# 0   terramind Segmentation       Terramind multimodal task for Segmantation
# 1             Segmentation  Generic template v1 and v2 models: Segmentation
# 2             Segmentation  Generic template v1 and v2 models: Segmentation
# 3             Segmentation  Generic template v1 and v2 models: Segmentation
# 4             Segmentation  Generic template v1 and v2 models: Segmentation
# 5             Segmentation  Generic template v1 and v2 models: Segmentation
# 6             Segmentation  Generic template v1 and v2 models: Segmentation
# 7             Segmentation  Generic template v1 and v2 models: Segmentation
# 8             Segmentation  Generic template v1 and v2 models: Segmentation
# 9             Segmentation  Generic template v1 and v2 models: Segmentation
# 10            Segmentation  Generic template v1 and v2 models: Segmentation
# 11            Segmentation  Generic template v1 and v2 models: Segmentation
# 12            Segmentation  Generic template v1 and v2 models: Segmentation
# 13            Segmentation  Generic template v1 and v2 models: Segmentation
# 14            Segmentation  Generic template v1 and v2 models: Segmentation
# 15            Segmentation  Generic template v1 and v2 models: Segmentation
# 16            Segmentation  Generic template v1 and v2 models: Segmentation
# 17            Segmentation  Generic template v1 and v2 models: Segmentation
# 18            Segmentation  Generic template v1 and v2 models: Segmentation
# 19            Segmentation  Generic template v1 and v2 models: Segmentation
# 20            Segmentation  Generic template v1 and v2 models: Segmentation
# 21            Segmentation  Generic template v1 and v2 models: Segmentation
# 22            Segmentation  Generic template v1 and v2 models: Segmentation
# 23            Segmentation  Generic template v1 and v2 models: Segmentation
# 24            Segmentation  Generic template v1 and v2 models: Segmentation
#
#          purpose                                         extra_info
# 0   Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 1   Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 2   Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 3   Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 4   Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 5   Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 6   Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 7   Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 8   Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 9   Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 10  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 11  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 12  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 13  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 14  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 15  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 16  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 17  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 18  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 19  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 20  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 21  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 22  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 23  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...
# 24  Segmentation  {'runtime_image': 'quay.io/geospatial-studio/t...

# %% [markdown]
# ---
# ### 3.3 Submit the training job
# ---
# - **Base Model**: Prithvi-EO-V2-300M
# - **Dataset**: Burn scars training data
# - **Task Template**: Segmentation template
# - **Name**: burn-scars-demo

# %%
# Create the fine-tuning payload
payload = {
    "name": "burn-scars-demo",
    "description": "Segmentation model for wildfire burn scar detection",
    "dataset_id": burn_scars_dataset_id,
    "base_model_id": prithvi_eo_v2_300m_base_model_id,
    "tune_template_id": segmentation_template_id,
}

print("📋 Fine-Tuning Configuration:")
print(json.dumps(payload, indent=2))
# Out:
# 📋 Fine-Tuning Configuration:
# {
#   "name": "burn-scars-demo",
#   "description": "Segmentation model for wildfire burn scar detection",
#   "dataset_id": "geodata-e8hwqfrvtsgwfgsx7agvgk",
#   "base_model_id": "28ad8b4f-13ba-4567-b28f-bb16758324c3",
#   "tune_template_id": "8573acf1-5ee7-4291-bcfe-357408080445"
# }

# %%
# Submit the fine-tuning job
print("\n🚀 Submitting fine-tuning job...\n")

tune_submitted = gfm_client.submit_tune(payload, output='json')

print("✅ Fine-tuning job submitted successfully!")
print(json.dumps(tune_submitted, indent=2))

# Save the tune ID for later use
tune_id = tune_submitted['tune_id']
print(f"\n📌 Tune ID: {tune_id}")
print("\nYou can monitor progress in the Studio UI under 'Start fine-tuning' > 'Model & Tunes'")

# %% [markdown]
# ## 4.0: Monitor Training Progress
#
# Training a geospatial foundation model takes time. We'll poll the status until completion.
#
# **What's happening during training:**
# 1. **Initialization**: Loading base model and dataset
# 2. **Training**: Iterating through epochs, updating model weights
# 3. **Validation**: Evaluating performance on validation set
# 4. **Checkpointing**: Saving model state periodically
# 5. **Completion**: Finalizing and storing the trained model
#
# **Expected Duration:**
# - Modern GPU (V100/A100): 30-45 minutes
# - Older GPU: 45-90 minutes
# - CPU: Not recommended (2 hrs + Using Terramind tiny )
#
# **Monitoring Options:**
# 1. **SDK Polling** (below): Automated status checks (Not recommended, use Studio UI instead)
# 2. **Studio UI**: Visual progress tracking with metrics

# %%
print("\n⚠️  IMPORTANT: Use the Studio UI to monitor training progress.")
print("The SDK polling is for automation only - it blocks execution and provides limited feedback.")
print("Go to your Studio UI → Fine-Tuning section to view real-time metrics and logs.\n")

# %% [markdown]
# ## 5.0: Run Inference with Trained Model
#
# Now that training is complete, let's test our model on new data! We'll run inference on the **Park Fire** from August 2024 in California.
#
# **Inference Configuration:**
#
# 1. **Spatial Domain**: Location and extent
#    - URL to input imagery
#    - Bounding box (optional)
#    - Tiles or polygons (optional)
#
# 2. **Temporal Domain**: Date(s) of imagery
#
# 3. **Model Settings**: Band configuration and scaling
#
# 4. **Post-Processing**: Masking options
#    - Cloud masking
#    - Ocean masking
#    - Snow/ice masking
#
# 5. **Visualization**: GeoServer layer configuration
#    - Input RGB layer
#    - Prediction layer with color mapping
#
# The inference pipeline consists of:
# 1. **URL Connector**: Fetch input data
# 2. **TerraTorch Inference**: Run model prediction
# 3. **Post-Processing**: Apply masks and filters
# 4. **GeoServer Push**: Publish results for visualization

# %%
# Define the inference payload
inference_payload = {
    "model_display_name": "geofm-sandbox-models",
    "location": "Red Bluff, California, United States",
    "description": "Park Fire Aug 2024",
    "spatial_domain": {
        "bbox": [],
        "urls": [
            "https://geospatial-studio-example-data.s3.us-east.cloud-object-storage.appdomain.cloud/examples-for-inference/park_fire_scaled.tif"
        ],
        "tiles": [],
        "polygons": []
    },
    "temporal_domain": [
        "2024-08-12"
    ],
    "pipeline_steps": [
        {
            "status": "READY",
            "process_id": "url-connector",
            "step_number": 0
        },
        {
            "status": "WAITING",
            "process_id": "terratorch-inference",
            "step_number": 1
        },
        {
            "status": "WAITING",
            "process_id": "postprocess-generic",
            "step_number": 2
        },
        {
            "status": "WAITING",
            "process_id": "push-to-geoserver",
            "step_number": 3
        }
    ],
    "post_processing": {
        "cloud_masking": "False",
        "ocean_masking": "False",
        "snow_ice_masking": None,
        "permanent_water_masking": "False"
    },
    "model_input_data_spec": [
        {
            "bands": [
                {
                    "index": "0",
                    "RGB_band": "B",
                    "band_name": "Blue",
                    "scaling_factor": "0.0001"
                },
                {
                    "index": "1",
                    "RGB_band": "G",
                    "band_name": "Green",
                    "scaling_factor": "0.0001"
                },
                {
                    "index": "2",
                    "RGB_band": "R",
                    "band_name": "Red",
                    "scaling_factor": "0.0001"
                },
                {
                    "index": "3",
                    "band_name": "NIR_Narrow",
                    "scaling_factor": "0.0001"
                },
                {
                    "index": "4",
                    "band_name": "SWIR1",
                    "scaling_factor": "0.0001"
                },
                {
                    "index": "5",
                    "band_name": "SWIR2",
                    "scaling_factor": "0.0001"
                }
            ],
            "connector": "sentinelhub",
            "collection": "hls_l30",
            "file_suffix": "_merged.tif",
            "modality_tag": "HLS_L30"
        }
    ],
    "geoserver_push": [
        {
            "z_index": 0,
            "workspace": "geofm",
            "layer_name": "input_rgb",
            "file_suffix": "",
            "display_name": "Input image (RGB)",
            "filepath_key": "model_input_original_image_rgb",
            "geoserver_style": {
                "rgb": [
                    {
                        "label": "RedChannel",
                        "channel": 1,
                        "maxValue": 255,
                        "minValue": 0
                    },
                    {
                        "label": "GreenChannel",
                        "channel": 2,
                        "maxValue": 255,
                        "minValue": 0
                    },
                    {
                        "label": "BlueChannel",
                        "channel": 3,
                        "maxValue": 255,
                        "minValue": 0
                    }
                ]
            },
            "visible_by_default": "True"
        },
        {
            "z_index": 1,
            "workspace": "geofm",
            "layer_name": "pred",
            "file_suffix": "",
            "display_name": "Model prediction",
            "filepath_key": "model_output_image",
            "geoserver_style": {
                "segmentation": [
                    {
                        "color": "#000000",
                        "label": "ignore",
                        "opacity": 0,
                        "quantity": "-1"
                    },
                    {
                        "color": "#000000",
                        "label": "no-data",
                        "opacity": 0,
                        "quantity": "0"
                    },
                    {
                        "color": "#ab4f4f",
                        "label": "fire-scar",
                        "opacity": 1,
                        "quantity": "1"
                    }
                ]
            },
            "visible_by_default": "True"
        }
    ],
    "tune_id" : "geotune-k9xhhztv6rqub8usa4xjdp"
}

print("📋 Inference Configuration:")
print(f"Location: {inference_payload['location']}")
print(f"Date: {inference_payload['temporal_domain'][0]}")
print(f"Model: {inference_payload['model_display_name']}")
# Out:
# 📋 Inference Configuration:
# Location: Red Bluff, California, United States
# Date: 2024-08-12
# Model: geofm-sandbox-models

# %%
# Submit the inference request
print("\n🚀 Submitting inference request...\n")
tune_id = "geotune-k9xhhztv6rqub8usa4xjdp"

inference_response = gfm_client.try_out_tune(tune_id=tune_id, data=inference_payload)

print("✅ Inference submitted successfully!")
print(json.dumps(inference_response, indent=2))

print("\n💡 Next Steps:")
print("1. Navigate to the Geospatial Studio UI")
print("2. Click on 'Start fine-tuning' card")
print("3. Under 'Model & Tunes', find 'burn-scars-demo'")
print("4. Under 'History', click on 'Park Fire Aug 2024'")
print("5. View the inference results on the map!")
# Out:
# 🚀 Submitting inference request...
#
# ✅ Inference submitted successfully!
# {
#   "spatial_domain": {
#     "bbox": [],
#     "polygons": [],
#     "tiles": [],
#     "urls": [
#       "https://geospatial-studio-example-data.s3.us-east.cloud-object-storage.appdomain.cloud/examples-for-inference/park_fire_scaled.tif"
#     ]
#   },
#   "temporal_domain": [
#     "2024-08-12"
#   ],
#   "fine_tuning_id": "geotune-k9xhhztv6rqub8usa4xjdp",
#   "generic_processor": null,
#   "maxcc": 100,
#   "model_display_name": "geofm-sandbox-models",
#   "description": "Park Fire Aug 2024",
#   "location": "Red Bluff, California, United States",
#   "geoserver_layers": null,
#   "demo": null,
#   "model_id": "36b15b7b-94d6-473b-87f4-aa848329bb55",
#   "inference_output": null,
#   "generic_processor_id": null,
#   "id": "f0b7fff7-a2bf-419e-b11e-21d66eb61955",
#   "active": true,
#   "created_by": "test@example.com",
#   "created_at": "2026-04-14T16:01:12.162156Z",
#   "updated_at": "2026-04-14T16:01:12.183463Z",
#   "status": "PENDING",
#   "tasks_count_total": 1,
#   "tasks_count_success": 0,
#   "tasks_count_failed": 0,
#   "tasks_count_stopped": 0,
#   "tasks_count_waiting": 1
# }
#
# 💡 Next Steps:
# 1. Navigate to the Geospatial Studio UI
# 2. Click on 'Start fine-tuning' card
# 3. Under 'Model & Tunes', find 'burn-scars-demo'
# 4. Under 'History', click on 'Park Fire Aug 2024'
# 5. View the inference results on the map!

# %% [markdown]
# ## 5.1. Viewing Results in the UI
#
# Your inference results are now available in the Geospatial Studio UI!
#
# **To view results:**
#
# 1. **Navigate to Model Catalog**
#    - Click "Start fine-tuning" on the home page
#    - Or go directly to the Model Catalog
#
# 2. **Find Your Model**
#    - Look for "burn-scars-demo" in the list
#    - Click on the model card
#
# 3. **View Inference History**
#    - Click on the "History" tab
#    - Find "Park Fire Aug 2024"
#    - Click to open the inference page
#
# 4. **Explore the Map**
#    - **Input RGB**: Original satellite imagery
#    - **Model Prediction**: Burn scar detection overlay (red areas)
#    - Use layer controls to toggle visibility
#    - Zoom and pan to explore details
#
# **What to Look For:**
# - Red areas indicate detected burn scars
# - Compare with the input imagery to validate results
# - Check for false positives/negatives
# - Assess model performance on this test case

# %% [markdown]
# ## 6.0 Advanced : Run inference on a previously trained model
#
# Now that you've completed the end-to-end workflow, let's see the inference output with a model trained for a longer duration
#
# ---

# %%
# The best model already onboarded in the cluster
best_burnscars_model = "geotune-mgmshlc8b9mwksedrghray"
# Run an inference on the best model
gfm_client.try_out_tune(tune_id=tune_id, data={**inference_payload, "description": "Best Model Inference", "tune_id":best_burnscars_model})


# Use 5.1 instructions to view the results in the UI
# Out:
# {'spatial_domain': {'bbox': [],
#   'polygons': [],
#   'tiles': [],
#   'urls': ['https://geospatial-studio-example-data.s3.us-east.cloud-object-storage.appdomain.cloud/examples-for-inference/park_fire_scaled.tif']},
#  'temporal_domain': ['2024-08-12'],
#  'fine_tuning_id': 'geotune-k9xhhztv6rqub8usa4xjdp',
#  'generic_processor': None,
#  'maxcc': 100,
#  'model_display_name': 'geofm-sandbox-models',
#  'description': 'Best Model Inference',
#  'location': 'Red Bluff, California, United States',
#  'geoserver_layers': None,
#  'demo': None,
#  'model_id': '36b15b7b-94d6-473b-87f4-aa848329bb55',
#  'inference_output': None,
#  'generic_processor_id': None,
#  'id': 'd402fe0d-6693-40e1-889c-35756e9b245c',
#  'active': True,
#  'created_by': 'test@example.com',
#  'created_at': '2026-04-14T16:06:30.943702Z',
#  'updated_at': '2026-04-14T16:06:30.967560Z',
#  'status': 'PENDING',
#  'tasks_count_total': 1,
#  'tasks_count_success': 0,
#  'tasks_count_failed': 0,
#  'tasks_count_stopped': 0,
#  'tasks_count_waiting': 1}

# %% [markdown]
# ## 7. Summary and Key Takeaways
#
# Congratulations! You've completed an end-to-end machine learning workflow for geospatial AI with a burnscars example. 🎉
#
# ### What You Accomplished
#
# ✅ **Submitted a fine-tuning job** (customized model for burn scar detection) with:
#    - A Prithvi-EO-V2-300M backbone
#    - A burn scars dataset with 804 labeled burn scar scenes
#    - Tracked training job status and completion
#    - Tested model on new wildfire data
#    - Viewed predictions in the UI
#    - Compared predictions with a better trained model
#
#
# ### Resources
#
# - **Documentation**: [Geospatial Studio Docs](https://terrastackai.github.io/geospatial-studio/)
# - **SDK Reference**: [Geospatial Studio SDK](https://terrastackai.github.io/geospatial-studio-toolkit/)
# - **Dataset**: [HLS Burn Scars on Hugging Face](https://huggingface.co/datasets/ibm-nasa-geospatial/hls_burn_scars)
# - **Foundation Models**: [IBM Geospatial Models](https://huggingface.co/ibm-nasa-geospatial)
#
# ---
# ### Next Steps
#
# - **Lab 7**: Complete end-to-end workflow with floods usecase
# - **Explore**: Using Multimodal models for predicting floods.
#
#
# Thank you for participating! We hope you found this workshop valuable and are excited to build geospatial AI applications with IBM Geospatial Studio.
#
# **Questions or Feedback?**
# - Open an issue on [GitHub](https://github.com/terrastackai/geospatial-studio)
# - Join our community discussions
# - Contact the development team
#
# Happy mapping! 🌍🛰️
